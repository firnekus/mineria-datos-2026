# %%
import pandas as pd
df = pd.read_csv("Performance_of_Stuednts.csv")

# %%
df.head()
# Out:
#    gender race/group parental education level         lunch test prep course  \
# 0  Female   Group 10        bachelor's degree      standard             none
# 1  Female   Group 20             some college      standard        completed
# 2  Female   Group 10          master's degree      standard             none
# 3    Male    Group 9       associate's degree  free/reduced             none
# 4    Male   Group 20             some college      standard             none
#
#    math score  science score  english score
# 0          66             72             74
# 1          69             90             88
# 2          90             88             93
# 3          47             57             44
# 4          76             44             75

# %%
df.columns
# Out:
# Index(['gender', 'race/group', 'parental education level', 'lunch',
#        'test prep course', 'math score', 'science score', 'english score'],
#       dtype='object')

# %%
df['gender'].value_counts().count()
# Out:
# np.int64(2)

# %% [markdown]
# Variables Categoricas del Dataset:
# *   Gender (Male/Female)
# *   Race/Group (Group 10, Group 20, Group 9, Group 8, Group 11)
# *   Lunch (Free/Reduced, Standard)
# *   Test Prep Course (None, Completed)
# *   Parental Education Level (Bachelor's Degree, Some College, Master's Degree, Associate's Degree, High School, Some High School)
#
# En total, 18 de estas variables son categóricas. Estas variables, a diferencia de las otras 3 numéricas, clasifican los resultados en función de los distintos factores mencionados.
